# %%
#pip install scikit-learn==1.5.0 joblib

# %%
#pip show scikit-learn

# %%
#pip show joblib

# %% [markdown]
# - [Introduction](#intro)
# - [Data Assessment and Cleaning](#da)
# - [Exploratory Data Analysis](#eda)
# - [Modeling](#mod)
# - [Conclusion](#conc)
# - [Recommendations](#rec)
# - [Limitations](#lit)

# %% [markdown]
# # Introduction
# <a name="intro"></a>
#
# - In this project, we aim to predict school completion rates of emerging countries using data analysis and machine learning methods.
# - We will explore the data, explain in detail, and give answers to the research questions below
# - > Which of the models gave a smaller predictive error
# - > What is the impact of feature engineering and feature selection on the performance of the model
# - > What is the impact of different hyper-parameters on the model performance

# %% [markdown]
# ##### The Data
# > The data used in this project was obtained from the SDG website.
# -

# %% [markdown]
# **Proportion of children/young people at the age of primary education prepared for the future in mathematics, both sexes (%): PCYPEPFM**
# **Proportion of children/young people at the age of lower secondary education prepared for the future in mathematics, both sexes (%): PCYPESFM**
# **Proportion of children/young people at the age of lower secondary education prepared for the future in reading, both sexes (%): PCYPELSFR**
# **Proportion of students at the end of primary education achieving at least a minimum proficiency level in reading, both sexes (%): PSPMPRBS**
# **Proportion of students at the end of lower secondary education achieving at least a minimum proficiency level in reading, both sexes (%): PSPMLSRBS**
# **Completion rate, primary education, not disabled, both sexes (%): CRPND**
# **Completion rate, primary education, disabled, both sexes (%): CRPD**
# **Completion rate, lower secondary education, not disabled, both sexes (%): CRLSND**
# **Completion rate, lower secondary education, disabled, both sexes (%): CRLSD**
# **Completion rate, upper secondary education, not disabled, both sexes (%): CRUSND**
# **Completion rate, upper secondary education, disabled, both sexes (%): CRUSD**
# **Gross intake ratio to the last grade of primary education, both sexes (%): GIP**
# **Gross intake ratio to the last grade of lower secondary general education, both sexes (%): GILS**
# **Out-of-school rate for children of primary school age, both sexes (%): OFSPSA**
# **Out-of-school rate for adolescents of lower secondary school age, both sexes (%): OFSALSSA**
# **Out-of-school rate for youth of upper secondary school age, both sexes (%): OFSUSSA**
# **Percentage of pupils enrolled in primary education who are at least 2 years over-age for their current grade, both sexes (%): PPP_2_CG**
# **Percentage of pupils enrolled in lower secondary education who are at least 2 years over-age for their current grade, both sexes (household survey data) (%): PPELS_2_CG**
# **Proportion of children aged 24-59 months who are developmentally on track in health, learning and psychosocial well-being, both sexes (%): PC_24_59_THLP**
# **Net enrolment rate, early childhood education, both sexes (%): NERECE**
# **Net enrolment rate, pre-primary, both sexes (%): NERPP**
# **Percentage of youth/adults who have achieved at least a minimum level of proficiency in digital literacy skills (%): PYALMLPDL**
# **Educational attainment rate, completed primary education or higher, population 25+ years, both sexes (%): EARCPEHP_25+**
# **Educational attainment rate, completed lower secondary education or higher, population 25+ years, both sexes (%): EARCLSHP_25+**
# **Educational attainment rate, completed upper secondary education or higher, population 25+ years, both sexes (%): EARCUSE_25+**
# **Number of attacks on students, personnel and institutions: NASPI**
# **Percentage of students experiencing bullying in the last 12 months in lower secondary education, adjusted gender parity index (GPIA): PSEB_12LSE**
# **Proportion of teachers with the minimum required qualifications in primary education, adjusted gender parity index (GPIA): PTMREPEAGPI**
# **Proportion of teachers with the minimum required qualifications in secondary education, adjusted gender parity index (GPIA): PTWMRSEAGPI**

# %% [markdown]
# # Data assesment and Cleaning
# <a id='da'></a>

# %%
import glob
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# To ensure the output of multiple lines of code cell is displayed in Jupyter notebbok:
# To activate this option per notebook basis, use the code below:

# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

# or
#from google.colab import drive
#drive.mount('/content/drive')

get_ipython().ast_node_interactivity = 'all'

# %%
#C:/Users/512GB/OneDrive/Documents/Hamoye/Project_1/Spring project/Hamoye_Spring_24_Project/
path = '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/*.csv'
#path = "C:/Users/Odunayo Grace/Downloads/Project data"
# Specifying the path to csv file
csv_files_list = glob.glob(path)

print(f"\nThe total number of csv files in the directory is: {len(csv_files_list)}.\n\n"
     "The list of the files include:- \n")
print(csv_files_list)
# Out:
# The total number of csv files in the directory is: 30.
#
# The list of the files include:-
#
# ['/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (28).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (12).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (7).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (24).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (25).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (33).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (6).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (13).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (29).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (34).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (22).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (18).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (14).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (15).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (19).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (23).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (35).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (20).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (16).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (17).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (21).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (5).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (10).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (9).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (26).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (30).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (31).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (27).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (8).csv', '/Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (11).csv']

# %%
# Create an empty list to store DataFrames
df_list = []

# loop through list of csv files and read each one into a dataframe and append to the df_list
for csv_file in csv_files_list:
    # read in csv
    temp_df = pd.read_csv(csv_file)

    # Cehckout the created DataFrame
    temp_df.head()

    # append each temp_df to the df_list
    df_list.append(temp_df)

    # Print a message to show the success of the operations above and
    # shape of each of the newly created temp_df
    print(f"\nSuccessfully created dataframe for {csv_file} with shape {temp_df.shape}\n")

    # print out the names of the columns in each DataFrame in temp_df
    print(temp_df.columns)

# Check the length of the DataFrames in the df_list
print(f"\nThe DataFrame list, df_list contains {len(df_list)} DataFrames "
f"with their corresponding shapes shown above\n")
# Out:
#        Country  Year  EARCPEHP_25+
# 0  Afghanistan  2014         13.68
# 1  Afghanistan  2015         19.59
# 2  Afghanistan  2017         24.28
# 3  Afghanistan  2020         22.43
# 4  Afghanistan  2021         15.25
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (28).csv with shape (1299, 3)
#
# Index(['Country', 'Year', 'EARCPEHP_25+'], dtype='object')
#       Country  Year   CRPD
# 0  Bangladesh  2011  34.41
# 1    Botswana  2011  82.22
# 2    Cambodia  2014  44.30
# 3    Cambodia  2021  37.13
# 4    Colombia  2010  63.30
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (12).csv with shape (23, 3)
#
# Index(['Country', 'Year', ' CRPD'], dtype='object')
#                       Country  Year  PCYPESFM
# 0  Iran (Islamic Republic of)  2011     20.88
# 1                  Kazakhstan  2012     54.50
# 2  Iran (Islamic Republic of)  2015     29.01
# 3                  Kazakhstan  2018     50.81
# 4                  Uzbekistan  2022     19.01
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (7).csv with shape (241, 3)
#
# Index(['Country', 'Year', 'PCYPESFM'], dtype='object')
#       Country  Year  PC_24_59_THLP
# 0     Algeria  2019          76.80
# 1   Argentina  2020          86.22
# 2  Bangladesh  2019          74.50
# 3    Barbados  2012          96.60
# 4     Belarus  2019          86.90
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (24).csv with shape (85, 3)
#
# Index(['Country', 'Year', 'PC_24_59_THLP'], dtype='object')
#    Country  Year  NERECE
# 0  Algeria  2010   70.01
# 1  Algeria  2011   66.70
# 2  Algeria  2021   50.65
# 3  Algeria  2022   53.19
# 4  Algeria  2023   52.43
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (25).csv with shape (1461, 3)
#
# Index(['Country', 'Year', 'NERECE'], dtype='object')
#        Country  Year  PSEB_12LSE
# 0  Afghanistan  2014        1.06
# 1      Albania  2014        0.77
# 2      Algeria  2011        1.13
# 3     Anguilla  2016        1.26
# 4    Argentina  2012        0.98
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (33).csv with shape (103, 3)
#
# Index(['Country', 'Year', 'PSEB_12LSE'], dtype='object')
#      Country  Year  PCYPEPFM
# 0    Albania  2019     60.05
# 1  Argentina  2013     19.83
# 2  Argentina  2019     12.61
# 3    Armenia  2011     40.67
# 4    Armenia  2015     54.25
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (6).csv with shape (176, 3)
#
# Index(['Country', 'Year', 'PCYPEPFM'], dtype='object')
#       Country  Year  CRLSND
# 0  Bangladesh  2011   54.04
# 1    Botswana  2011   83.78
# 2    Cambodia  2014   40.80
# 3    Cambodia  2021   56.44
# 4    Colombia  2010   73.10
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (13).csv with shape (23, 3)
#
# Index(['Country', 'Year', 'CRLSND'], dtype='object')
#        Country  Year  EARCLSHP_25+
# 0  Afghanistan  2014         10.99
# 1  Afghanistan  2015         13.13
# 2  Afghanistan  2017         16.00
# 3  Afghanistan  2020         16.78
# 4  Afghanistan  2021         11.63
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (29).csv with shape (1326, 3)
#
# Index(['Country', 'Year', 'EARCLSHP_25+'], dtype='object')
#    Country  Year  PTMREPEAGPI
# 0  Albania  2021         0.83
# 1  Algeria  2014         1.00
# 2  Algeria  2015         1.00
# 3  Algeria  2021         1.00
# 4  Algeria  2022         1.01
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (34).csv with shape (1057, 3)
#
# Index(['Country', 'Year', 'PTMREPEAGPI'], dtype='object')
#    Country  Year  PPP_2_CG
# 0  Albania  2010      2.94
# 1  Albania  2011      2.70
# 2  Albania  2012      2.44
# 3  Albania  2013      2.68
# 4  Albania  2014      2.26
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (22).csv with shape (1708, 3)
#
# Index(['Country', 'Year', 'PPP_2_CG'], dtype='object')
#        Country  Year   GIlS
# 0  Afghanistan  2016  52.52
# 1  Afghanistan  2017  54.69
# 2  Afghanistan  2018  56.74
# 3  Afghanistan  2019  59.72
# 4      Albania  2010  99.68
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (18).csv with shape (1739, 3)
#
# Index(['Country', 'Year', ' GIlS'], dtype='object')
#       Country  Year   CRLSD
# 0  Bangladesh  2011   21.32
# 1    Botswana  2011   70.35
# 2    Cambodia  2014    3.90
# 3    Cambodia  2021   13.52
# 4    Colombia  2010   46.90
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (14).csv with shape (23, 3)
#
# Index(['Country', 'Year', ' CRLSD'], dtype='object')
#               Country  Year  CRUSND
# 0          Bangladesh  2011   13.31
# 1            Botswana  2011   54.08
# 2            Cambodia  2021   26.81
# 3  Dominican Republic  2010   49.43
# 4            Maldives  2017   40.75
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (15).csv with shape (19, 3)
#
# Index(['Country', 'Year', 'CRUSND'], dtype='object')
#    Country  Year   OFSPSA
# 0  Albania  2010     0.12
# 1  Albania  2011     0.17
# 2  Albania  2012     0.22
# 3  Albania  2013     0.37
# 4  Albania  2016     1.15
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (19).csv with shape (1811, 3)
#
# Index(['Country', 'Year', ' OFSPSA'], dtype='object')
#        Country  Year  PPELS_2_CG
# 0  Afghanistan  2015       15.94
# 1  Afghanistan  2022       22.94
# 2      Albania  2017        1.22
# 3      Algeria  2019       20.38
# 4       Angola  2015       62.22
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (23).csv with shape (283, 3)
#
# Index(['Country', 'Year', 'PPELS_2_CG'], dtype='object')
#    Country  Year  PTWMRSEAGPI
# 0  Albania  2020         0.91
# 1  Albania  2021         0.91
# 2  Andorra  2013         1.00
# 3  Andorra  2014         1.00
# 4  Andorra  2015         1.00
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (35).csv with shape (772, 3)
#
# Index(['Country', 'Year', 'PTWMRSEAGPI'], dtype='object')
#    Country  Year  OFSALSSA
# 0  Albania  2013      1.20
# 1  Albania  2014      1.38
# 2  Albania  2015      0.97
# 3  Albania  2016      1.38
# 4  Albania  2017      1.40
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (20).csv with shape (1554, 3)
#
# Index(['Country', 'Year', 'OFSALSSA'], dtype='object')
#               Country  Year  CRUSD
# 0  Dominican Republic  2010  44.51
# 1              Zambia  2010  10.69
# 2         Philippines  2010  45.46
# 3         Puerto Rico  2010  64.59
# 4               Nepal  2011  10.59
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (16).csv with shape (19, 3)
#
# Index(['Country', 'Year', 'CRUSD'], dtype='object')
#        Country  Year     GIP
# 0  Afghanistan  2016   82.91
# 1  Afghanistan  2017   87.25
# 2  Afghanistan  2018   88.74
# 3  Afghanistan  2019   86.18
# 4      Albania  2010  103.27
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (17).csv with shape (1780, 3)
#
# Index(['Country', 'Year', 'GIP'], dtype='object')
#        Country  Year  OFSUSSA
# 0  Afghanistan  2013    51.55
# 1  Afghanistan  2014    54.37
# 2  Afghanistan  2015    55.46
# 3  Afghanistan  2016    57.68
# 4  Afghanistan  2017    56.16
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (21).csv with shape (1617, 3)
#
# Index(['Country', 'Year', 'OFSUSSA'], dtype='object')
#        Country  Year  GEEDUV
# 0  Afghanistan  2010    3.48
# 1  Afghanistan  2011    3.46
# 2  Afghanistan  2012    2.60
# 3  Afghanistan  2013    3.45
# 4  Afghanistan  2014    3.70
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (5).csv with shape (2093, 3)
#
# Index(['Country', 'Year', 'GEEDUV'], dtype='object')
#    Country  Year  PSPMLSRBS
# 0  Albania  2012      47.66
# 1  Albania  2015      49.72
# 2  Albania  2018      47.76
# 3  Albania  2022      26.29
# 4  Algeria  2015      21.03
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (10).csv with shape (285, 3)
#
# Index(['Country', 'Year', 'PSPMLSRBS'], dtype='object')
#      Country  Year  PSPMPRBS
# 0    Albania  2021     92.12
# 1  Argentina  2013     32.50
# 2  Argentina  2019     31.90
# 3    Austria  2011     97.10
# 4    Austria  2016     97.59
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (9).csv with shape (206, 3)
#
# Index(['Country', 'Year', 'PSPMPRBS'], dtype='object')
#    Country  Year   NERPP
# 0  Albania  2010   66.20
# 1  Albania  2011   70.17
# 2  Albania  2012   75.41
# 3  Albania  2013   77.26
# 4  Albania  2014   76.65
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (26).csv with shape (1684, 3)
#
# Index(['Country', 'Year', ' NERPP'], dtype='object')
#               Country  Year  EARCUSE_25+
# 0               Kenya  2010        22.03
# 1            Slovakia  2010        84.25
# 2             Georgia  2010        52.02
# 3  Russian Federation  2010        84.99
# 4            Portugal  2010        25.60
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (30).csv with shape (1327, 3)
#
# Index(['Country', 'Year', 'EARCUSE_25+'], dtype='object')
#        Country  Year  NASPI
# 0  Afghanistan  2013    199
# 1  Afghanistan  2014    229
# 2  Afghanistan  2015    314
# 3  Afghanistan  2016    143
# 4  Afghanistan  2017    115
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (31).csv with shape (837, 3)
#
# Index(['Country', 'Year', 'NASPI'], dtype='object')
#    Country  Year  PYALMLPDL
# 0  Austria  2012         32
# 1  Belgium  2012         35
# 2   Canada  2012         37
# 3    Chile  2015         15
# 4  Czechia  2012         33
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (27).csv with shape (31, 3)
#
# Index(['Country', 'Year', 'PYALMLPDL'], dtype='object')
#    Country  Year  PCYPELSFR
# 0  Albania  2012      45.77
# 1  Albania  2015      47.86
# 2  Albania  2018      46.07
# 3  Albania  2022      25.43
# 4  Algeria  2015      13.01
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (8).csv with shape (233, 3)
#
# Index(['Country', 'Year', 'PCYPELSFR'], dtype='object')
#       Country  Year  CRPND
# 0  Bangladesh  2011  76.00
# 1    Botswana  2011  93.43
# 2    Cambodia  2014  72.50
# 3    Cambodia  2021  83.01
# 4    Colombia  2010  91.10
# Successfully created dataframe for /Users/user/Documents/HAMOYE/Hamoye_Spring_24_Project-master 3/SDG_Feb2024_ (11).csv with shape (23, 3)
#
# Index(['Country', 'Year', 'CRPND'], dtype='object')
#
# The DataFrame list, df_list contains 30 DataFrames with their corresponding shapes shown above

# %%
# concatenate our list of dataframes, df_list, into one single DataFrame, df_total
df_total = pd.concat(df_list, axis=1)

# Check the shape of the concatenated DataFrame, df_total
print(f"\nThe final concatenated DataFrame, df_total, contains {df_total.shape[0]} observations "
      f"and {df_total.shape[1]} features\n")

# Check the first five observations
df_total.head()
# Out:
# The final concatenated DataFrame, df_total, contains 2093 observations and 90 features
#        Country    Year  EARCPEHP_25+     Country    Year   CRPD  \
# 0  Afghanistan  2014.0         13.68  Bangladesh  2011.0  34.41
# 1  Afghanistan  2015.0         19.59    Botswana  2011.0  82.22
# 2  Afghanistan  2017.0         24.28    Cambodia  2014.0  44.30
# 3  Afghanistan  2020.0         22.43    Cambodia  2021.0  37.13
# 4  Afghanistan  2021.0         15.25    Colombia  2010.0  63.30
#
#                       Country    Year  PCYPESFM     Country  ...  NASPI  \
# 0  Iran (Islamic Republic of)  2011.0     20.88     Algeria  ...  199.0
# 1                  Kazakhstan  2012.0     54.50   Argentina  ...  229.0
# 2  Iran (Islamic Republic of)  2015.0     29.01  Bangladesh  ...  314.0
# 3                  Kazakhstan  2018.0     50.81    Barbados  ...  143.0
# 4                  Uzbekistan  2022.0     19.01     Belarus  ...  115.0
#
#    Country    Year  PYALMLPDL  Country    Year  PCYPELSFR     Country    Year  \
# 0  Austria  2012.0       32.0  Albania  2012.0      45.77  Bangladesh  2011.0
# 1  Belgium  2012.0       35.0  Albania  2015.0      47.86    Botswana  2011.0
# 2   Canada  2012.0       37.0  Albania  2018.0      46.07    Cambodia  2014.0
# 3    Chile  2015.0       15.0  Albania  2022.0      25.43    Cambodia  2021.0
# 4  Czechia  2012.0       33.0  Algeria  2015.0      13.01    Colombia  2010.0
#
#    CRPND
# 0  76.00
# 1  93.43
# 2  72.50
# 3  83.01
# 4  91.10
#
# [5 rows x 90 columns]

# %%
# Check the information about the datatypes in the DatFrame
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2093 entries, 0 to 2092
# Data columns (total 90 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country        1299 non-null   object
#  1   Year           1299 non-null   float64
#  2   EARCPEHP_25+   1299 non-null   float64
#  3   Country        23 non-null     object
#  4   Year           23 non-null     float64
#  5    CRPD          23 non-null     float64
#  6   Country        241 non-null    object
#  7   Year           241 non-null    float64
#  8   PCYPESFM       241 non-null    float64
#  9   Country        85 non-null     object
#  10  Year           85 non-null     float64
#  11  PC_24_59_THLP  85 non-null     float64
#  12  Country        1461 non-null   object
#  13  Year           1461 non-null   float64
#  14  NERECE         1461 non-null   float64
#  15  Country        103 non-null    object
#  16  Year           103 non-null    float64
#  17  PSEB_12LSE     103 non-null    float64
#  18  Country        176 non-null    object
#  19  Year           176 non-null    float64
#  20  PCYPEPFM       176 non-null    float64
#  21  Country        23 non-null     object
#  22  Year           23 non-null     float64
#  23  CRLSND         23 non-null     float64
#  24  Country        1326 non-null   object
#  25  Year           1326 non-null   float64
#  26  EARCLSHP_25+   1326 non-null   float64
#  27  Country        1057 non-null   object
#  28  Year           1057 non-null   float64
#  29  PTMREPEAGPI    1057 non-null   float64
#  30  Country        1708 non-null   object
#  31  Year           1708 non-null   float64
#  32  PPP_2_CG       1708 non-null   float64
#  33  Country        1739 non-null   object
#  34  Year           1739 non-null   float64
#  35   GIlS          1739 non-null   float64
#  36  Country        23 non-null     object
#  37  Year           23 non-null     float64
#  38   CRLSD         23 non-null     float64
#  39  Country        19 non-null     object
#  40  Year           19 non-null     float64
#  41  CRUSND         19 non-null     float64
#  42  Country        1811 non-null   object
#  43  Year           1811 non-null   float64
#  44   OFSPSA        1811 non-null   float64
#  45  Country        283 non-null    object
#  46  Year           283 non-null    float64
#  47  PPELS_2_CG     283 non-null    float64
#  48  Country        772 non-null    object
#  49  Year           772 non-null    float64
#  50  PTWMRSEAGPI    772 non-null    float64
#  51  Country        1554 non-null   object
#  52  Year           1554 non-null   float64
#  53  OFSALSSA       1554 non-null   float64
#  54  Country        19 non-null     object
#  55  Year           19 non-null     float64
#  56  CRUSD          19 non-null     float64
#  57  Country        1780 non-null   object
#  58  Year           1780 non-null   float64
#  59  GIP            1780 non-null   float64
#  60  Country        1617 non-null   object
#  61  Year           1617 non-null   float64
#  62  OFSUSSA        1617 non-null   float64
#  63  Country        2093 non-null   object
#  64  Year           2093 non-null   int64
#  65  GEEDUV         2093 non-null   float64
#  66  Country        285 non-null    object
#  67  Year           285 non-null    float64
#  68  PSPMLSRBS      285 non-null    float64
#  69  Country        206 non-null    object
#  70  Year           206 non-null    float64
#  71  PSPMPRBS       206 non-null    float64
#  72  Country        1684 non-null   object
#  73  Year           1684 non-null   float64
#  74   NERPP         1684 non-null   float64
#  75  Country        1327 non-null   object
#  76  Year           1327 non-null   float64
#  77  EARCUSE_25+    1327 non-null   float64
#  78  Country        837 non-null    object
#  79  Year           837 non-null    float64
#  80  NASPI          837 non-null    float64
#  81  Country        31 non-null     object
#  82  Year           31 non-null     float64
#  83  PYALMLPDL      31 non-null     float64
#  84  Country        233 non-null    object
#  85  Year           233 non-null    float64
#  86  PCYPELSFR      233 non-null    float64
#  87  Country        23 non-null     object
#  88  Year           23 non-null     float64
#  89  CRPND          23 non-null     float64
# dtypes: float64(59), int64(1), object(30)
# memory usage: 1.4+ MB

# %% [markdown]
# From the output of the `df_total.info()` command above, we will notice that there are inconsistencies in the column names, with some have trailing spaces and the column names have a mixture of cases- upper, lower and sentence cases.
#
# We shall attempt to correct ths and make all column names uniformly lowercase.
# However, we first need to convert the datatype of the column names from `object` to `string`.
#
# When NA values are present, the output dtype is `float64`. Similarly for methods returning boolean values.

# %%
# Convert column names from object to string datatype so we can run string operations on them
df_total.columns = df_total.columns.astype('string')
df_total.columns
# Out:
# Index(['Country', 'Year', 'EARCPEHP_25+', 'Country', 'Year', ' CRPD',
#        'Country', 'Year', 'PCYPESFM', 'Country', 'Year', 'PC_24_59_THLP',
#        'Country', 'Year', 'NERECE', 'Country', 'Year', 'PSEB_12LSE', 'Country',
#        'Year', 'PCYPEPFM', 'Country', 'Year', 'CRLSND', 'Country', 'Year',
#        'EARCLSHP_25+', 'Country', 'Year', 'PTMREPEAGPI', 'Country', 'Year',
#        'PPP_2_CG', 'Country', 'Year', ' GIlS', 'Country', 'Year', ' CRLSD',
#        'Country', 'Year', 'CRUSND', 'Country', 'Year', ' OFSPSA', 'Country',
#        'Year', 'PPELS_2_CG', 'Country', 'Year', 'PTWMRSEAGPI', 'Country',
#        'Year', 'OFSALSSA', 'Country', 'Year', 'CRUSD', 'Country', 'Year',
#        'GIP', 'Country', 'Year', 'OFSUSSA', 'Country', 'Year', 'GEEDUV',
#        'Country', 'Year', 'PSPMLSRBS', 'Country', 'Year', 'PSPMPRBS',
#        'Country', 'Year', ' NERPP', 'Country', 'Year', 'EARCUSE_25+',
#        'Country', 'Year', 'NASPI', 'Country', 'Year', 'PYALMLPDL', 'Country',
#        'Year', 'PCYPELSFR', 'Country', 'Year', 'CRPND'],
#       dtype='string')

# %% [markdown]
# There are two ways to store text data in pandas:
#
# 1. `object` -dtype NumPy array.
#
# 2. [`StringDtype`](https://pandas.pydata.org/docs/reference/api/pandas.StringDtype.html#pandas.StringDtype "pandas.StringDtype") extension type.
#
#
# We recommend using [`StringDtype`](https://pandas.pydata.org/docs/reference/api/pandas.StringDtype.html#pandas.StringDtype "pandas.StringDtype") to store text data.
#
# Prior to pandas 1.0, `object` dtype was the only option. This was unfortunate for many reasons:
#
# 1. You can accidentally store a _mixture_ of strings and non-strings in an `object` dtype array. It’s better to have a dedicated dtype.
#
# 2. `object` dtype breaks dtype-specific operations like [`DataFrame.select_dtypes()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.select_dtypes.html#pandas.DataFrame.select_dtypes "pandas.DataFrame.select_dtypes"). There isn’t a clear way to select _just_ text while excluding non-text but still object-dtype columns.
#
# 3. When reading code, the contents of an `object` dtype array is less clear than `'string'`.

# %%
# Remove trailing spaces in column names and
# Convert column names to lowercase for uniformity
df_total.columns = df_total.columns.str.strip().str.lower()

# Check to see if we are successful
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2093 entries, 0 to 2092
# Data columns (total 90 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        1299 non-null   object
#  1   year           1299 non-null   float64
#  2   earcpehp_25+   1299 non-null   float64
#  3   country        23 non-null     object
#  4   year           23 non-null     float64
#  5   crpd           23 non-null     float64
#  6   country        241 non-null    object
#  7   year           241 non-null    float64
#  8   pcypesfm       241 non-null    float64
#  9   country        85 non-null     object
#  10  year           85 non-null     float64
#  11  pc_24_59_thlp  85 non-null     float64
#  12  country        1461 non-null   object
#  13  year           1461 non-null   float64
#  14  nerece         1461 non-null   float64
#  15  country        103 non-null    object
#  16  year           103 non-null    float64
#  17  pseb_12lse     103 non-null    float64
#  18  country        176 non-null    object
#  19  year           176 non-null    float64
#  20  pcypepfm       176 non-null    float64
#  21  country        23 non-null     object
#  22  year           23 non-null     float64
#  23  crlsnd         23 non-null     float64
#  24  country        1326 non-null   object
#  25  year           1326 non-null   float64
#  26  earclshp_25+   1326 non-null   float64
#  27  country        1057 non-null   object
#  28  year           1057 non-null   float64
#  29  ptmrepeagpi    1057 non-null   float64
#  30  country        1708 non-null   object
#  31  year           1708 non-null   float64
#  32  ppp_2_cg       1708 non-null   float64
#  33  country        1739 non-null   object
#  34  year           1739 non-null   float64
#  35  gils           1739 non-null   float64
#  36  country        23 non-null     object
#  37  year           23 non-null     float64
#  38  crlsd          23 non-null     float64
#  39  country        19 non-null     object
#  40  year           19 non-null     float64
#  41  crusnd         19 non-null     float64
#  42  country        1811 non-null   object
#  43  year           1811 non-null   float64
#  44  ofspsa         1811 non-null   float64
#  45  country        283 non-null    object
#  46  year           283 non-null    float64
#  47  ppels_2_cg     283 non-null    float64
#  48  country        772 non-null    object
#  49  year           772 non-null    float64
#  50  ptwmrseagpi    772 non-null    float64
#  51  country        1554 non-null   object
#  52  year           1554 non-null   float64
#  53  ofsalssa       1554 non-null   float64
#  54  country        19 non-null     object
#  55  year           19 non-null     float64
#  56  crusd          19 non-null     float64
#  57  country        1780 non-null   object
#  58  year           1780 non-null   float64
#  59  gip            1780 non-null   float64
#  60  country        1617 non-null   object
#  61  year           1617 non-null   float64
#  62  ofsussa        1617 non-null   float64
#  63  country        2093 non-null   object
#  64  year           2093 non-null   int64
#  65  geeduv         2093 non-null   float64
#  66  country        285 non-null    object
#  67  year           285 non-null    float64
#  68  pspmlsrbs      285 non-null    float64
#  69  country        206 non-null    object
#  70  year           206 non-null    float64
#  71  pspmprbs       206 non-null    float64
#  72  country        1684 non-null   object
#  73  year           1684 non-null   float64
#  74  nerpp          1684 non-null   float64
#  75  country        1327 non-null   object
#  76  year           1327 non-null   float64
#  77  earcuse_25+    1327 non-null   float64
#  78  country        837 non-null    object
#  79  year           837 non-null    float64
#  80  naspi          837 non-null    float64
#  81  country        31 non-null     object
#  82  year           31 non-null     float64
#  83  pyalmlpdl      31 non-null     float64
#  84  country        233 non-null    object
#  85  year           233 non-null    float64
#  86  pcypelsfr      233 non-null    float64
#  87  country        23 non-null     object
#  88  year           23 non-null     float64
#  89  crpnd          23 non-null     float64
# dtypes: float64(59), int64(1), object(30)
# memory usage: 1.4+ MB

# %%
# Check the DataFrame for the number and types of datatypes it contains
df_total.dtypes.nunique()
df_total.dtypes.unique()
# Out:
# 3
# array([dtype('O'), dtype('float64'), dtype('int64')], dtype=object)

# %%
# Separate the columns based on datatypes

# For the numerical columns
numerical_cols_df = df_total.select_dtypes('number')
numerical_cols_df.info()
print("#########" * 20)
# For the categorical columns
categorical_cols_df = df_total.select_dtypes('object')
categorical_cols_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2093 entries, 0 to 2092
# Data columns (total 60 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           1299 non-null   float64
#  1   earcpehp_25+   1299 non-null   float64
#  2   year           23 non-null     float64
#  3   crpd           23 non-null     float64
#  4   year           241 non-null    float64
#  5   pcypesfm       241 non-null    float64
#  6   year           85 non-null     float64
#  7   pc_24_59_thlp  85 non-null     float64
#  8   year           1461 non-null   float64
#  9   nerece         1461 non-null   float64
#  10  year           103 non-null    float64
#  11  pseb_12lse     103 non-null    float64
#  12  year           176 non-null    float64
#  13  pcypepfm       176 non-null    float64
#  14  year           23 non-null     float64
#  15  crlsnd         23 non-null     float64
#  16  year           1326 non-null   float64
#  17  earclshp_25+   1326 non-null   float64
#  18  year           1057 non-null   float64
#  19  ptmrepeagpi    1057 non-null   float64
#  20  year           1708 non-null   float64
#  21  ppp_2_cg       1708 non-null   float64
#  22  year           1739 non-null   float64
#  23  gils           1739 non-null   float64
#  24  year           23 non-null     float64
#  25  crlsd          23 non-null     float64
#  26  year           19 non-null     float64
#  27  crusnd         19 non-null     float64
#  28  year           1811 non-null   float64
#  29  ofspsa         1811 non-null   float64
#  30  year           283 non-null    float64
#  31  ppels_2_cg     283 non-null    float64
#  32  year           772 non-null    float64
#  33  ptwmrseagpi    772 non-null    float64
#  34  year           1554 non-null   float64
#  35  ofsalssa       1554 non-null   float64
#  36  year           19 non-null     float64
#  37  crusd          19 non-null     float64
#  38  year           1780 non-null   float64
#  39  gip            1780 non-null   float64
#  40  year           1617 non-null   float64
#  41  ofsussa        1617 non-null   float64
#  42  year           2093 non-null   int64
#  43  geeduv         2093 non-null   float64
#  44  year           285 non-null    float64
#  45  pspmlsrbs      285 non-null    float64
#  46  year           206 non-null    float64
#  47  pspmprbs       206 non-null    float64
#  48  year           1684 non-null   float64
#  49  nerpp          1684 non-null   float64
#  50  year           1327 non-null   float64
#  51  earcuse_25+    1327 non-null   float64
#  52  year           837 non-null    float64
#  53  naspi          837 non-null    float64
#  54  year           31 non-null     float64
#  55  pyalmlpdl      31 non-null     float64
#  56  year           233 non-null    float64
#  57  pcypelsfr      233 non-null    float64
#  58  year           23 non-null     float64
#  59  crpnd          23 non-null     float64
# dtypes: float64(59), int64(1)
# memory usage: 981.2 KB
# ####################################################################################################################################################################################
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2093 entries, 0 to 2092
# Data columns (total 30 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  1299 non-null   object
#  1   country  23 non-null     object
#  2   country  241 non-null    object
#  3   country  85 non-null     object
#  4   country  1461 non-null   object
#  5   country  103 non-null    object
#  6   country  176 non-null    object
#  7   country  23 non-null     object
#  8   country  1326 non-null   object
#  9   country  1057 non-null   object
#  10  country  1708 non-null   object
#  11  country  1739 non-null   object
#  12  country  23 non-null     object
#  13  country  19 non-null     object
#  14  country  1811 non-null   object
#  15  country  283 non-null    object
#  16  country  772 non-null    object
#  17  country  1554 non-null   object
#  18  country  19 non-null     object
#  19  country  1780 non-null   object
#  20  country  1617 non-null   object
#  21  country  2093 non-null   object
#  22  country  285 non-null    object
#  23  country  206 non-null    object
#  24  country  1684 non-null   object
#  25  country  1327 non-null   object
#  26  country  837 non-null    object
#  27  country  31 non-null     object
#  28  country  233 non-null    object
#  29  country  23 non-null     object
# dtypes: object(30)
# memory usage: 490.7+ KB

# %%
df_total['country']
# Out:
#           country     country                     country     country  \
# 0     Afghanistan  Bangladesh  Iran (Islamic Republic of)     Algeria
# 1     Afghanistan    Botswana                  Kazakhstan   Argentina
# 2     Afghanistan    Cambodia  Iran (Islamic Republic of)  Bangladesh
# 3     Afghanistan    Cambodia                  Kazakhstan    Barbados
# 4     Afghanistan    Colombia                  Uzbekistan     Belarus
# ...           ...         ...                         ...         ...
# 2088          NaN         NaN                         NaN         NaN
# 2089          NaN         NaN                         NaN         NaN
# 2090          NaN         NaN                         NaN         NaN
# 2091          NaN         NaN                         NaN         NaN
# 2092          NaN         NaN                         NaN         NaN
#
#       country      country    country     country      country  country  ...  \
# 0     Algeria  Afghanistan    Albania  Bangladesh  Afghanistan  Albania  ...
# 1     Algeria      Albania  Argentina    Botswana  Afghanistan  Algeria  ...
# 2     Algeria      Algeria  Argentina    Cambodia  Afghanistan  Algeria  ...
# 3     Algeria     Anguilla    Armenia    Cambodia  Afghanistan  Algeria  ...
# 4     Algeria    Argentina    Armenia    Colombia  Afghanistan  Algeria  ...
# ...       ...          ...        ...         ...          ...      ...  ...
# 2088      NaN          NaN        NaN         NaN          NaN      NaN  ...
# 2089      NaN          NaN        NaN         NaN          NaN      NaN  ...
# 2090      NaN          NaN        NaN         NaN          NaN      NaN  ...
# 2091      NaN          NaN        NaN         NaN          NaN      NaN  ...
# 2092      NaN          NaN        NaN         NaN          NaN      NaN  ...
#
#           country      country  country    country  country  \
# 0     Afghanistan  Afghanistan  Albania    Albania  Albania
# 1     Afghanistan  Afghanistan  Albania  Argentina  Albania
# 2     Afghanistan  Afghanistan  Albania  Argentina  Albania
# 3     Afghanistan  Afghanistan  Albania    Austria  Albania
# 4     Afghanistan  Afghanistan  Algeria    Austria  Albania
# ...           ...          ...      ...        ...      ...
# 2088          NaN     Zimbabwe      NaN        NaN      NaN
# 2089          NaN     Zimbabwe      NaN        NaN      NaN
# 2090          NaN     Zimbabwe      NaN        NaN      NaN
# 2091          NaN     Zimbabwe      NaN        NaN      NaN
# 2092          NaN     Zimbabwe      NaN        NaN      NaN
#
#                  country      country  country  country     country
# 0                  Kenya  Afghanistan  Austria  Albania  Bangladesh
# 1               Slovakia  Afghanistan  Belgium  Albania    Botswana
# 2                Georgia  Afghanistan   Canada  Albania    Cambodia
# 3     Russian Federation  Afghanistan    Chile  Albania    Cambodia
# 4               Portugal  Afghanistan  Czechia  Algeria    Colombia
# ...                  ...          ...      ...      ...         ...
# 2088                 NaN          NaN      NaN      NaN         NaN
# 2089                 NaN          NaN      NaN      NaN         NaN
# 2090                 NaN          NaN      NaN      NaN         NaN
# 2091                 NaN          NaN      NaN      NaN         NaN
# 2092                 NaN          NaN      NaN      NaN         NaN
#
# [2093 rows x 30 columns]

# %% [markdown]
# From the output of the code cell above, it is obvious that the DataFrame contains multiple `country` columns. In addition, it is the only categorical column in our DataFrame.

# %%
numerical_cols_df.head()
categorical_cols_df.head()
# Out:
#      year  earcpehp_25+    year   crpd    year  pcypesfm    year  \
# 0  2014.0         13.68  2011.0  34.41  2011.0     20.88  2019.0
# 1  2015.0         19.59  2011.0  82.22  2012.0     54.50  2020.0
# 2  2017.0         24.28  2014.0  44.30  2015.0     29.01  2019.0
# 3  2020.0         22.43  2021.0  37.13  2018.0     50.81  2012.0
# 4  2021.0         15.25  2010.0  63.30  2022.0     19.01  2019.0
#
#    pc_24_59_thlp    year  nerece  ...    year  earcuse_25+    year  naspi  \
# 0          76.80  2010.0   70.01  ...  2010.0        22.03  2013.0  199.0
# 1          86.22  2011.0   66.70  ...  2010.0        84.25  2014.0  229.0
# 2          74.50  2021.0   50.65  ...  2010.0        52.02  2015.0  314.0
# 3          96.60  2022.0   53.19  ...  2010.0        84.99  2016.0  143.0
# 4          86.90  2023.0   52.43  ...  2010.0        25.60  2017.0  115.0
#
#      year  pyalmlpdl    year  pcypelsfr    year  crpnd
# 0  2012.0       32.0  2012.0      45.77  2011.0  76.00
# 1  2012.0       35.0  2015.0      47.86  2011.0  93.43
# 2  2012.0       37.0  2018.0      46.07  2014.0  72.50
# 3  2015.0       15.0  2022.0      25.43  2021.0  83.01
# 4  2012.0       33.0  2015.0      13.01  2010.0  91.10
#
# [5 rows x 60 columns]
#        country     country                     country     country  country  \
# 0  Afghanistan  Bangladesh  Iran (Islamic Republic of)     Algeria  Algeria
# 1  Afghanistan    Botswana                  Kazakhstan   Argentina  Algeria
# 2  Afghanistan    Cambodia  Iran (Islamic Republic of)  Bangladesh  Algeria
# 3  Afghanistan    Cambodia                  Kazakhstan    Barbados  Algeria
# 4  Afghanistan    Colombia                  Uzbekistan     Belarus  Algeria
#
#        country    country     country      country  country  ...      country  \
# 0  Afghanistan    Albania  Bangladesh  Afghanistan  Albania  ...  Afghanistan
# 1      Albania  Argentina    Botswana  Afghanistan  Algeria  ...  Afghanistan
# 2      Algeria  Argentina    Cambodia  Afghanistan  Algeria  ...  Afghanistan
# 3     Anguilla    Armenia    Cambodia  Afghanistan  Algeria  ...  Afghanistan
# 4    Argentina    Armenia    Colombia  Afghanistan  Algeria  ...  Afghanistan
#
#        country  country    country  country             country      country  \
# 0  Afghanistan  Albania    Albania  Albania               Kenya  Afghanistan
# 1  Afghanistan  Albania  Argentina  Albania            Slovakia  Afghanistan
# 2  Afghanistan  Albania  Argentina  Albania             Georgia  Afghanistan
# 3  Afghanistan  Albania    Austria  Albania  Russian Federation  Afghanistan
# 4  Afghanistan  Algeria    Austria  Albania            Portugal  Afghanistan
#
#    country  country     country
# 0  Austria  Albania  Bangladesh
# 1  Belgium  Albania    Botswana
# 2   Canada  Albania    Cambodia
# 3    Chile  Albania    Cambodia
# 4  Czechia  Algeria    Colombia
#
# [5 rows x 30 columns]

# %%
# Check for missing values in the numerical columns dataframe
numerical_cols_df.isnull().sum()
# Out:
# year              794
# earcpehp_25+      794
# year             2070
# crpd             2070
# year             1852
# pcypesfm         1852
# year             2008
# pc_24_59_thlp    2008
# year              632
# nerece            632
# year             1990
# pseb_12lse       1990
# year             1917
# pcypepfm         1917
# year             2070
# crlsnd           2070
# year              767
# earclshp_25+      767
# year             1036
# ptmrepeagpi      1036
# year              385
# ppp_2_cg          385
# year              354
# gils              354
# year             2070
# crlsd            2070
# year             2074
# crusnd           2074
# year              282
# ofspsa            282
# year             1810
# ppels_2_cg       1810
# year             1321
# ptwmrseagpi      1321
# year              539
# ofsalssa          539
# year             2074
# crusd            2074
# year              313
# gip               313
# year              476
# ofsussa           476
# year                0
# geeduv              0
# year             1808
# pspmlsrbs        1808
# year             1887
# pspmprbs         1887
# year              409
# nerpp             409
# year              766
# earcuse_25+       766
# year             1256
# naspi            1256
# year             2062
# pyalmlpdl        2062
# year             1860
# pcypelsfr        1860
# year             2070
# crpnd            2070
# dtype: int64

# %%
# Check for missing values in the categorical columns dataframe
categorical_cols_df.isnull().sum()
# Out:
# country     794
# country    2070
# country    1852
# country    2008
# country     632
# country    1990
# country    1917
# country    2070
# country     767
# country    1036
# country     385
# country     354
# country    2070
# country    2074
# country     282
# country    1810
# country    1321
# country     539
# country    2074
# country     313
# country     476
# country       0
# country    1808
# country    1887
# country     409
# country     766
# country    1256
# country    2062
# country    1860
# country    2070
# dtype: int64

# %% [markdown]
# Next let us handle the missing values by imputing the median values. There are various ways to handle missing values. We can either choose to delete all the observations with missing values or impute either the mean, median or mode of the observations.
#
# In our case, the misisng values are much, therefore deleting them will reduce the number of observations we have. We therefore choose to impute the median value.

# %%
# get a list of all the numerical column names
num_col_list = list(numerical_cols_df.columns)

for col in num_col_list:
    numerical_cols_df[col] = numerical_cols_df[col].fillna(numerical_cols_df[col].median())

numerical_cols_df.isnull().sum()
# Out:
# year             0
# earcpehp_25+     0
# year             0
# crpd             0
# year             0
# pcypesfm         0
# year             0
# pc_24_59_thlp    0
# year             0
# nerece           0
# year             0
# pseb_12lse       0
# year             0
# pcypepfm         0
# year             0
# crlsnd           0
# year             0
# earclshp_25+     0
# year             0
# ptmrepeagpi      0
# year             0
# ppp_2_cg         0
# year             0
# gils             0
# year             0
# crlsd            0
# year             0
# crusnd           0
# year             0
# ofspsa           0
# year             0
# ppels_2_cg       0
# year             0
# ptwmrseagpi      0
# year             0
# ofsalssa         0
# year             0
# crusd            0
# year             0
# gip              0
# year             0
# ofsussa          0
# year             0
# geeduv           0
# year             0
# pspmlsrbs        0
# year             0
# pspmprbs         0
# year             0
# nerpp            0
# year             0
# earcuse_25+      0
# year             0
# naspi            0
# year             0
# pyalmlpdl        0
# year             0
# pcypelsfr        0
# year             0
# crpnd            0
# dtype: int64

# %% [markdown]
# From the result of the code cell output above, we have successfully handled the missing values in our numerical dataframe by imputing the median values for each column.

# %%
numerical_cols_df.describe().T
# Out:
#                 count         mean        std      min      25%       50%  \
# year           2093.0  2016.570951   2.862088  2010.00  2015.00  2017.000
# earcpehp_25+   2093.0    87.020889  17.561356     0.00    87.89    93.000
# year           2093.0  2016.969900   0.493313  2010.00  2017.00  2017.000
# crpd           2093.0    41.858829   2.880588     0.00    41.84    41.840
# year           2093.0  2016.959388   1.255113  2011.00  2017.00  2017.000
# pcypesfm       2093.0    63.218323   8.838628     1.05    64.31    64.310
# year           2093.0  2017.007167   0.554355  2010.00  2017.00  2017.000
# pc_24_59_thlp  2093.0    78.070941   2.860494    36.20    78.19    78.190
# year           2093.0  2016.593407   2.993699  2010.00  2015.00  2017.000
# nerece         2093.0    49.942962  22.532262     0.00    36.61    50.610
# year           2093.0  2016.838509   0.799563  2010.00  2017.00  2017.000
# pseb_12lse     2093.0     0.908634   0.036744     0.37     0.91     0.910
# year           2093.0  2016.876254   1.028037  2011.00  2017.00  2017.000
# pcypepfm       2093.0    52.090196   9.166252     0.54    52.73    52.730
# year           2093.0  2016.969900   0.493313  2010.00  2017.00  2017.000
# crlsnd         2093.0    62.162566   2.780756     4.58    62.20    62.200
# year           2093.0  2016.522695   2.912866  2010.00  2015.00  2017.000
# earclshp_25+   2093.0    72.178827  20.794518     0.00    64.71    76.645
# year           2093.0  2016.621118   2.652657  2010.00  2016.00  2017.000
# ptmrepeagpi    2093.0     1.013473   0.124324     0.00     1.00     1.000
# year           2093.0  2016.471094   3.222138  2010.00  2014.00  2017.000
# ppp_2_cg       2093.0     7.672289  12.129845     0.00     0.90     2.500
# year           2093.0  2016.126135   3.409349  2010.00  2013.00  2017.000
# gils           2093.0    80.665442  25.286189     0.00    71.64    88.980
# year           2093.0  2016.969900   0.493313  2010.00  2017.00  2017.000
# crlsd          2093.0    21.397420   2.797121     0.00    21.32    21.320
# year           2093.0  2016.979455   0.437333  2010.00  2017.00  2017.000
# crusnd         2093.0    40.723373   2.246464     1.50    40.75    40.750
# year           2093.0  2016.079790   3.435118  2010.00  2013.00  2017.000
# ofspsa         2093.0     6.430855   9.397308     0.00     1.31     3.120
# year           2093.0  2016.978978   1.203698  2010.00  2017.00  2017.000
# ppels_2_cg     2093.0    19.213144   5.802666     0.10    18.87    18.870
# year           2093.0  2016.821309   2.214066  2010.00  2017.00  2017.000
# ptwmrseagpi    2093.0     1.006355   0.110145     0.00     1.00     1.000
# year           2093.0  2016.408027   3.144204  2010.00  2014.00  2017.000
# ofsalssa       2093.0     9.610117  13.238627     0.00     2.17     4.875
# year           2093.0  2016.979455   0.437333  2010.00  2017.00  2017.000
# crusd          2093.0     9.660459   1.959387     0.00     9.60     9.600
# year           2093.0  2016.003822   3.430404  2010.00  2013.00  2017.000
# gip            2093.0    91.193982  16.997482     0.00    89.26    96.345
# year           2093.0  2016.392738   3.205305  2010.00  2014.00  2017.000
# ofsussa        2093.0    23.206183  19.129212     0.00    10.20    18.030
# year           2093.0  2015.947922   3.637580  2010.00  2013.00  2016.000
# geeduv         2093.0     4.415968   1.875801     0.00     3.15     4.240
# year           2093.0  2017.014333   1.354048  2012.00  2017.00  2017.000
# pspmlsrbs      2093.0    71.507544   7.959016     5.04    72.53    72.530
# year           2093.0  2016.943622   1.193383  2011.00  2017.00  2017.000
# pspmprbs       2093.0    74.502418  10.845004     1.80    75.57    75.570
# year           2093.0  2016.240803   3.321567  2010.00  2014.00  2017.000
# nerpp          2093.0    60.238617  26.511288     0.00    41.08    66.155
# year           2093.0  2016.501672   2.926542  2010.00  2015.00  2017.000
# earcuse_25+    2093.0    55.309341  20.243100     0.00    45.92    56.450
# year           2093.0  2017.114668   1.790735  2013.00  2017.00  2017.000
# naspi          2093.0    14.143813  58.615184     0.00     2.00     2.000
# year           2093.0  2016.949355   0.477321  2012.00  2017.00  2017.000
# pyalmlpdl      2093.0    27.995700   1.386731     5.00    28.00    28.000
# year           2093.0  2016.975633   1.205817  2012.00  2017.00  2017.000
# pcypelsfr      2093.0    68.328414   7.608748     2.22    69.24    69.240
# year           2093.0  2016.969900   0.493313  2010.00  2017.00  2017.000
# crpnd          2093.0    79.882112   2.280587    26.28    79.94    79.940
#
#                    75%      max
# year           2018.00  2023.00
# earcpehp_25+     96.28   100.00
# year           2017.00  2021.00
# crpd             41.84    96.60
# year           2017.00  2022.00
# pcypesfm         64.31    90.82
# year           2017.00  2022.00
# pc_24_59_thlp    78.19    97.20
# year           2018.00  2023.00
# nerece           63.79    99.96
# year           2017.00  2017.00
# pseb_12lse        0.91     1.26
# year           2017.00  2023.00
# pcypepfm         52.73    96.81
# year           2017.00  2021.00
# crlsnd           62.20    96.15
# year           2018.00  2023.00
# earclshp_25+     84.17   100.00
# year           2017.00  2023.00
# ptmrepeagpi       1.00     2.00
# year           2019.00  2023.00
# ppp_2_cg          8.68    85.75
# year           2018.00  2023.00
# gils             96.22   196.34
# year           2017.00  2021.00
# crlsd            21.32    84.40
# year           2017.00  2021.00
# crusnd           40.75    88.29
# year           2019.00  2023.00
# ofspsa            6.88    63.03
# year           2017.00  2023.00
# ppels_2_cg       18.87    81.67
# year           2017.00  2023.00
# ptwmrseagpi       1.00     1.84
# year           2018.00  2023.00
# ofsalssa         10.14    79.68
# year           2017.00  2021.00
# crusd             9.60    64.59
# year           2018.00  2023.00
# gip              99.46   152.81
# year           2018.00  2023.00
# ofsussa          28.31    93.36
# year           2019.00  2023.00
# geeduv            5.42    16.58
# year           2017.00  2022.00
# pspmlsrbs        72.53    93.21
# year           2017.00  2023.00
# pspmprbs         75.57    99.55
# year           2018.00  2023.00
# nerpp            78.78    99.96
# year           2018.00  2023.00
# earcuse_25+      69.05    97.40
# year           2017.00  2022.00
# naspi             2.00   842.00
# year           2017.00  2017.00
# pyalmlpdl        28.00    44.00
# year           2017.00  2022.00
# pcypelsfr        69.24    92.31
# year           2017.00  2021.00
# crpnd            79.94    99.68

# %% [markdown]
# From the above, we can also notice that we have multiple `year` columns.

# %%
Cleaned_data= numerical_cols_df.drop(columns=['year'], axis=1)

# %% [markdown]
# # Exploratory Data Analysis
# <a id='eda'></a>
#
# - We will divide our analysis into, Univariate analysis, bivariate analysis, and multivariate analysis

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Question1 (What is the distribution of the numerical features ?)

# %%
Cleaned_data.columns
# Out:
# Index(['earcpehp_25+', 'crpd', 'pcypesfm', 'pc_24_59_thlp', 'nerece',
#        'pseb_12lse', 'pcypepfm', 'crlsnd', 'earclshp_25+', 'ptmrepeagpi',
#        'ppp_2_cg', 'gils', 'crlsd', 'crusnd', 'ofspsa', 'ppels_2_cg',
#        'ptwmrseagpi', 'ofsalssa', 'crusd', 'gip', 'ofsussa', 'geeduv',
#        'pspmlsrbs', 'pspmprbs', 'nerpp', 'earcuse_25+', 'naspi', 'pyalmlpdl',
#        'pcypelsfr', 'crpnd'],
#       dtype='string')

# %%
#create histogram plots to see the distribution of different numerical variables
columns= ['pspmlsrbs', 'crpnd', 'crpd', 'crlsnd', 'crlsd', 'crusnd', 'crusd',
       'gip', 'gils', 'ofspsa', 'ofsalssa',]


Cleaned_data[columns].hist( bins=20, figsize=(15,10))
plt.savefig('charts_1.png');

# %%
#create histogram plots to see the distribution of different numerical variables
columns= ['ofsussa', 'ppp_2_cg',
       'ppels_2_cg', 'pc_24_59_thlp', 'nerece', 'nerpp', 'pyalmlpdl',
       'earcpehp_25+', 'earclshp_25+', 'earcuse_25+', 'naspi']


Cleaned_data[columns].hist( bins=20, figsize=(15,10))
plt.savefig('charts_1.png');

# %%
#create histogram plots to see the distribution of different numerical variables
columns= ['pseb_12lse',
       'ptmrepeagpi', 'ptwmrseagpi', 'geeduv', 'pcypepfm', 'pcypesfm',
       'pcypelsfr', 'pspmprbs']


Cleaned_data[columns].hist( bins=20, figsize=(15,10))
plt.savefig('charts_1.png');

# %% [markdown]
# - From the distribution plots of the numerical features above, it is obvious that most of the variables are not normally distributed as most are either left skewed or rigt skewed, Hence, we will subsequnetly normalize the data in order to have a well processed data for our machine learning model.
# - Also the explanations for the impact of the distribution of each varible will be explained as we further on in the exploration phase of the work.

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# #### Question(How do some variables relate with the Completion rate of  primary education students who are not disabled)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure the figure size is large enough to accommodate all subplots
plt.rcParams["figure.figsize"] = (20, 15)

# Define the list of categories to plot against 'CRPND'
categories = ['nerpp', 'pyalmlpdl',
       'earcpehp_25+', 'earclshp_25+', 'earcuse_25+', 'naspi', 'pseb_12lse',
       'ptmrepeagpi', 'ptwmrseagpi', 'geeduv', 'pcypepfm', 'pcypesfm',
       'pcypelsfr']

# Create a subplot for each category
for idx, x in enumerate(categories):
    plt.subplot(4, 4, idx + 1)
    sns.regplot(data=Cleaned_data, x=x, y='crpnd')
    plt.title(f'Relationship between {x} and Completion rate')

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show();

# %% [markdown]
# - From the bivariate regression plots above, we intend showing how each variables relate with the completion rate. It is obvious that most of the variables do not have a linear relationship with the Completion rate of primary education students who are not disabled. Hence depicting that they many not be good predictors of school completion rate, however, we will apply some feature selection methods to still check and explore further on which of them to retain or remove

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure the figure size is large enough to accommodate all subplots
plt.rcParams["figure.figsize"] = (20, 15)

# Define the list of categories to plot against 'CRPND'
categories = ['pspmprbs', 'pspmlsrbs',  'gip', 'gils', 'ofspsa', 'ofsalssa', 'ofsussa', 'ppp_2_cg',
       'ppels_2_cg', 'pc_24_59_thlp', 'nerece']

# Create a subplot for each category
for idx, x in enumerate(categories):
    plt.subplot(4, 4, idx + 1)
    sns.regplot(data=Cleaned_data, x=x, y='crpnd')
    plt.title(f'Relationship between {x} and Completion rate ')

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show();

# %% [markdown]
# - From the bivariate regression plots above, we intend showing how each variables relate with the completion rate. It is obvious that most of the variables do not have a linear relationship with the Completion rate of primary education students who are not disabled. Hence depicting that they many not be good predictors of school completion rate, however, we will apply some feature selection methods to still check and explore further on which of them to retain or remove

# %%
# Ensure the figure size is large enough to accommodate all subplots
plt.rcParams["figure.figsize"] = (20, 15)

# Define the list of categories to plot against 'CRPND'
categories = ['nerece', 'nerpp', 'pyalmlpdl',
       'earcpehp_25+', 'earclshp_25+', 'earcuse_25+', 'naspi', 'pseb_12lse',
       'ptmrepeagpi', 'ptwmrseagpi', 'geeduv', 'pcypepfm', 'pcypesfm',
       'pcypelsfr']

# Create a subplot for each category
for idx, x in enumerate(categories):
    plt.subplot(4, 4, idx + 1)
    sns.regplot(data=Cleaned_data, x=x, y='crpd')
    plt.title(f'Relationship between {x} and Completion rate')

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show();

# %%
# Ensure the figure size is large enough to accommodate all subplots
plt.rcParams["figure.figsize"] = (20, 15)

# Define the list of categories to plot against 'CRPND'
categories = ['pspmprbs', 'pspmlsrbs',  'gip', 'gils', 'ofspsa', 'ofsalssa', 'ofsussa', 'ppp_2_cg',
       'ppels_2_cg', 'pc_24_59_thlp', 'nerece',]

# Create a subplot for each category
for idx, x in enumerate(categories):
    plt.subplot(4, 4, idx + 1)
    sns.regplot(data=Cleaned_data, x=x, y='crpd')
    plt.title(f'Relationship between {x} and Completion rate')

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show();

# %% [markdown]
# ## Multivariate Analysis

# %%
plt.figure(figsize=[25, 20])
sns.heatmap(data=Cleaned_data.corr(), annot=True, fmt=".2f", cmap='coolwarm', linewidths=.5)
# Show the plot
plt.title('Correlation plot for relationship between all the numerical variables', fontsize=20)
plt.show();

# %% [markdown]
# # Machine Learning Section
# **Machine learninh models to consider**
# - Elastic
# - Random forest
# - Xgboost
# - gradient boosting
# - MLP (non -linearity)

# %%
Cleaned_data.columns
# Out:
# Index(['earcpehp_25+', 'crpd', 'pcypesfm', 'pc_24_59_thlp', 'nerece',
#        'pseb_12lse', 'pcypepfm', 'crlsnd', 'earclshp_25+', 'ptmrepeagpi',
#        'ppp_2_cg', 'gils', 'crlsd', 'crusnd', 'ofspsa', 'ppels_2_cg',
#        'ptwmrseagpi', 'ofsalssa', 'crusd', 'gip', 'ofsussa', 'geeduv',
#        'pspmlsrbs', 'pspmprbs', 'nerpp', 'earcuse_25+', 'naspi', 'pyalmlpdl',
#        'pcypelsfr', 'crpnd'],
#       dtype='string')

# %%
y_columns = ['crpd', 'crpnd', 'crlsd', 'crlsnd', 'crusnd', 'crusd']
x = Cleaned_data.drop(columns=y_columns)
y = Cleaned_data[y_columns]

# %% [markdown]
# #### Split the data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=40)
print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (1674, 24)
# x_test shape: (419, 24)
# y_train shape: (1674, 6)
# y_test shape: (419, 6)

# %% [markdown]
# #### Further splitting the data into cross validation sets

# %%
# Splitting the train set into train and cross validation, 70% of 80% for Train and 30% of 80% for cross validation.
#x_train, x_cv, y_train, y_cv = train_test_split(x_train, y_train, test_size=0.31, random_state=40)

#print("x_train shape:", x_train.shape)
#print("x_cv shape:", x_cv.shape)
#print("y_train shape:", y_train.shape)
#print("y_cv shape:", y_cv.shape)

# %% [markdown]
# #### Feature selection using the "Variance Inflation Factor (VIF)" method.

# %%
# Utility function to return the VIF value for each feature provided
#from statsmodels.stats.outliers_influence import variance_inflation_factor

def compute_vif(x, Cleaned_data):
    """
    Returns a DataFrame containing features and their corresponding variance inflation factor
    features: list of features whoes multicollinearity check is needed
    df: DataFrame of the data under review
    """
    from statsmodels.stats.outliers_influence import variance_inflation_factor
    import pandas as pd
    X = Cleaned_data[x]
    X['intercept'] = 1
    # Create dataframe to store vif values
    vif = pd.DataFrame()
    vif['Feature'] = X.columns
    vif['Vif Factor'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif = vif[vif['Feature']!='intercept'].sort_values('Vif Factor', ascending=False)
    return vif


def select_features(train_df, threshold):

    """Returns two objects;
    1. a DataFrame containing features and their corresponding variance inflation factor, and
    2. Pandas Index object containing the list of features that have the least Multicollinearity in accordance with
        the supplied threshold.
    train_df: The training dataset whoes Multicollinearity is to be checked
    threshold: value to compare VIF value with, above which, the feature droped
    """
    data = train_df.copy()
    flag = True
    while flag:
        features_to_consider = data.columns
        # Calling the "compute_vif" utility function the Variance Inflation Factor dataframe
        sorted_vif_df = (compute_vif(features_to_consider, data).reset_index().drop('index', axis=1))

        # Get the highest vif value to compare against a threshold
        highest_vif = sorted_vif_df.at[0, 'Vif Factor']

        # Compare the highest_vif with a threshold (5 was decided for this problem by the team)
        if highest_vif > threshold: # or highest_vif=='inf':
            # Select the feature corresponding to the highest_vif (index 0 for both)
            feature = sorted_vif_df.at[0, 'Feature']
            # Drop the feature
            data.drop(feature, axis=1, inplace=True)

        else:
            flag = False
    return sorted_vif_df, data.columns

# %%
threshold = 5
vif_df, features = select_features(x_train, threshold)

# %% [markdown]
# ####  display the VIF dataframe and the selected features

# %%
display(vif_df)
print(features)
# Out:
#           Feature  Vif Factor
# 0       pcypelsfr    1.171428
# 1    earcpehp_25+    1.148651
# 2       pspmlsrbs    1.139286
# 3    earclshp_25+    1.134501
# 4        pcypesfm    1.119235
# 5        pcypepfm    1.114289
# 6           nerpp    1.097232
# 7            gils    1.094586
# 8         ofsussa    1.089311
# 9             gip    1.079891
# 10     pseb_12lse    1.065561
# 11  pc_24_59_thlp    1.060346
# 12       ppp_2_cg    1.056382
# 13         nerece    1.054676
# 14       pspmprbs    1.052089
# 15       ofsalssa    1.049219
# 16     ppels_2_cg    1.048767
# 17         geeduv    1.042158
# 18          naspi    1.042141
# 19    ptmrepeagpi    1.041432
# 20         ofspsa    1.037000
# 21    ptwmrseagpi    1.032744
# 22    earcuse_25+    1.031692
# 23      pyalmlpdl    1.030886
# Index(['earcpehp_25+', 'pcypesfm', 'pc_24_59_thlp', 'nerece', 'pseb_12lse',
#        'pcypepfm', 'earclshp_25+', 'ptmrepeagpi', 'ppp_2_cg', 'gils', 'ofspsa',
#        'ppels_2_cg', 'ptwmrseagpi', 'ofsalssa', 'gip', 'ofsussa', 'geeduv',
#        'pspmlsrbs', 'pspmprbs', 'nerpp', 'earcuse_25+', 'naspi', 'pyalmlpdl',
#        'pcypelsfr'],
#       dtype='string')

# %% [markdown]
# #### Making a dataframe with the selected features

# %%
# make a dataframe of the selected features
X_train = x_train[features]
X_train.head()
# Out:
#       earcpehp_25+  pcypesfm  pc_24_59_thlp  nerece  pseb_12lse  pcypepfm  \
# 1549         93.00     64.31          78.19   50.61        0.91     52.73
# 1457         93.00     64.31          78.19   38.42        0.91     52.73
# 554          76.86     64.31          78.19   66.31        0.91     52.73
# 2081         93.00     64.31          78.19   50.61        0.91     52.73
# 151          82.64     71.40          78.19   69.09        0.91     68.47
#
#       earclshp_25+  ptmrepeagpi  ppp_2_cg   gils  ...      gip  ofsussa  \
# 1549        76.645         1.00     22.63  94.94  ...   85.590     4.73
# 1457        76.645         1.00      0.20  83.19  ...   95.440    27.44
# 554         47.290         1.10     11.39  71.67  ...   92.850     7.09
# 2081        76.645         1.00      2.50  88.98  ...   96.345    18.03
# 151         57.490         1.15      1.35  63.68  ...  104.470    34.88
#
#       geeduv  pspmlsrbs  pspmprbs   nerpp  earcuse_25+  naspi  pyalmlpdl  \
# 1549    4.61      72.53     75.57  10.620        56.45    2.0       28.0
# 1457    7.33      72.53     75.57  29.640        56.45    2.0       28.0
# 554     7.07      72.53     75.57  30.190        49.15  183.0       28.0
# 2081    3.95      72.53     75.57  66.155        56.45    2.0       28.0
# 151     2.45      77.83     94.18  97.920        26.72    4.0       28.0
#
#       pcypelsfr
# 1549      69.24
# 1457      69.24
# 554       69.24
# 2081      69.24
# 151       83.39
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Normalization and standardization

# %%
# Normalizing and Standardizing the train data.
from sklearn.preprocessing import MinMaxScaler, StandardScaler
min_max_scaler = MinMaxScaler()
stand_scaler = StandardScaler()
#min_max_norm_data = min_max_scaler.fit_transform(X_train)
X_train_scaled = pd.DataFrame(stand_scaler.fit_transform(X_train), columns=X_train.columns, index=X_train.index)
X_test_scaled = pd.DataFrame(stand_scaler.transform(x_test[features]), columns=X_train.columns, index=x_test.index)

# %%
print(X_train_scaled[:3])
# Out:
#       earcpehp_25+  pcypesfm  pc_24_59_thlp    nerece  pseb_12lse  pcypepfm  \
# 1549      0.345389  0.129167       0.054014  0.040443    0.035561  0.056268
# 1457      0.345389  0.129167       0.054014 -0.498585    0.035561  0.056268
# 554      -0.546877  0.129167       0.054014  0.734679    0.035561  0.056268
#
#       earclshp_25+  ptmrepeagpi  ppp_2_cg      gils  ...       gip   ofsussa  \
# 1549      0.203470    -0.119748  1.306845  0.583895  ... -0.318244 -0.966549
# 1457      0.203470    -0.119748 -0.633343  0.126356  ...  0.263335  0.224018
# 554      -1.224034     0.674773  0.334589 -0.322227  ...  0.110413 -0.842826
#
#         geeduv  pspmlsrbs  pspmprbs     nerpp  earcuse_25+     naspi  \
# 1549  0.101334   0.130067  0.090827 -1.879994     0.045627 -0.207758
# 1457  1.550741   0.130067  0.090827 -1.165365     0.045627 -0.207758
# 554   1.412195   0.130067  0.090827 -1.144700    -0.311117  2.746084
#
#       pyalmlpdl  pcypelsfr
# 1549   0.017634   0.123184
# 1457   0.017634   0.123184
# 554    0.017634   0.123184
#
# [3 rows x 24 columns]

# %%
print(X_test_scaled[:3])
# Out:
#       earcpehp_25+  pcypesfm  pc_24_59_thlp    nerece  pseb_12lse  pcypepfm  \
# 1404      0.345389  0.129167       0.054014  0.561341    0.035561  0.056268
# 1723      0.345389  0.129167       0.054014  0.040443    0.035561  0.056268
# 1230      0.649997  0.129167       0.054014  1.241427    0.035561  0.056268
#
#       earclshp_25+  ptmrepeagpi  ppp_2_cg      gils  ...       gip   ofsussa  \
# 1404      0.203470    -0.119748 -0.614313  0.662163  ...  2.240115  1.305017
# 1723      0.203470    -0.119748 -0.434394 -1.357628  ...  0.625273 -0.269299
# 1230      0.594204    -0.119748 -0.303779  0.015768  ...  0.105099 -0.945055
#
#         geeduv  pspmlsrbs  pspmprbs     nerpp  earcuse_25+     naspi  \
# 1404 -0.495480   0.130067  0.090827  0.396523     0.045627 -0.207758
# 1723 -0.426207   0.130067  0.090827  0.206594     0.045627 -0.207758
# 1230 -0.292989   0.130067  0.090827  0.637363    -0.113686 -0.207758
#
#       pyalmlpdl  pcypelsfr
# 1404   0.017634   0.123184
# 1723   0.017634   0.123184
# 1230   0.017634   0.123184
#
# [3 rows x 24 columns]

# %% [markdown]
# #### Modeling
# <a id='mod'></a>

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
def evaluate_model(model, x, y):
    """
    Utility function to print the model performance, (MAE and MAPE)
    model: Fitted model
    x: cross validation features dataset
    y: cross validation target values
    """
    predicted = model.predict(x) #get predictions
    mae = mean_absolute_error(y_true=y, y_pred=predicted)
    rmse = mean_squared_error(y, predicted)

    print('MAE: {:.2f}'.format(mae))
    print('RMSE: {:.2f}'.format(rmse))
    print()

# %% [markdown]
# #### Modeling with Different Base Regressors

# %%
#pip install xgboost

# %%
from sklearn.linear_model import ElasticNet
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Dictionary of base regressors
base_regressors_dict = {
    'Elastic net': ElasticNet(),
    'RF Regressor': RandomForestRegressor(random_state=0),
    'xgboost': XGBRegressor(),
    'Gradient Boost': GradientBoostingRegressor(random_state=0),
    'MLP': MLPRegressor()
}

# Function to evaluate the model
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred, multioutput='raw_values')
    mae = mean_absolute_error(y_test, y_pred, multioutput='raw_values')
    print(f"MSE: {mse}")
    print(f"MAE: {mae}")

# Wrapping and evaluating each model with MultiOutputRegressor
for key, model in base_regressors_dict.items():
    multi_output_model = MultiOutputRegressor(model)
    multi_output_model.fit(X_train_scaled, y_train)
    print(f'Performance of "{key}" on Test set:')
    print('==' * 28)
    print('Test set:')
    print("**" * 8)
    evaluate_model(multi_output_model, X_test_scaled, y_test)
    print('\n')
# Out:
# MultiOutputRegressor(estimator=ElasticNet())
# Performance of "Elastic net" on Test set:
# ========================================================
# Test set:
# ****************
# MSE: [12.23968919  5.58941058 10.81415035  8.98656609  9.07000619  3.48759572]
# MAE: [0.36858173 0.32357727 0.39810011 0.38899657 0.34757865 0.22691069]
# MultiOutputRegressor(estimator=RandomForestRegressor(random_state=0))
# Performance of "RF Regressor" on Test set:
# ========================================================
# Test set:
# ****************
# MSE: [ 9.57524658  5.13600049  9.5485217  10.76601954 12.25609079  4.46950537]
# MAE: [0.34933652 0.27775274 0.36901862 0.37961026 0.41068711 0.23862482]
# MultiOutputRegressor(estimator=XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=None,
#                                             grow_policy=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=None, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             random_state=None, ...))
# Performance of "xgboost" on Test set:
# ========================================================
# Test set:
# ****************
# MSE: [ 7.31199769  5.1261151   7.95917734 10.22029839 21.24183636  2.33334306]
# MAE: [0.26155455 0.24574395 0.3256591  0.37822336 0.53162275 0.14622768]
# MultiOutputRegressor(estimator=GradientBoostingRegressor(random_state=0))
# Performance of "Gradient Boost" on Test set:
# ========================================================
# Test set:
# ****************
# MSE: [ 8.64924943  4.62963248  9.37016203 11.88386823 10.97809878  3.15716518]
# MAE: [0.33948117 0.25951509 0.33509486 0.36834898 0.41233402 0.18840958]
# MultiOutputRegressor(estimator=MLPRegressor())
# Performance of "MLP" on Test set:
# ========================================================
# Test set:
# ****************
# MSE: [ 36.23273991 107.21962336  14.33868975  58.57835018  27.73897852
#    2.87297167]
# MAE: [3.47371269 7.55225132 1.53285942 5.14666916 3.24862972 0.54427577]

# %% [markdown]
# ##### Models Result
# - The Gradient Boosting Regressor has the lowest MSE and MAE values overall, indicating better performance compared to the other models.
# - The Random Forest Regressor also shows competitive performance.
# - **Conclusion**
# - Based on the performance metrics (MSE and MAE), the Gradient Boosting Regressor is the best model among the MultiOutputRegressor estimators evaluated. It exhibits the lowest MSE and MAE values across most target variables, indicating better predictive capability. Therefore, the Gradient Boosting Regressor should be chosen as the best MultiOutputRegressor model for this task.

# %% [markdown]
# #### Retraining the best model ()

# %%
# Define the base model
base_model = GradientBoostingRegressor(random_state=0)

# Create MultiOutputRegressor with the base model
multi_output_model = MultiOutputRegressor(base_model)

# Fit the MultiOutputRegressor model
multi_output_model.fit(X_train_scaled, y_train)

# Evaluate the model
print('Performance of Gradient Boost on Test set:')
print('==' * 28)
print('Test set:')
print("**" * 8)
evaluate_model(multi_output_model, X_test_scaled, y_test)
print('\n')
# Out:
# MultiOutputRegressor(estimator=GradientBoostingRegressor(random_state=0))
# Performance of Gradient Boost on Test set:
# ========================================================
# Test set:
# ****************
# MSE: [ 8.64924943  4.62963248  9.37016203 11.88386823 10.97809878  3.15716518]
# MAE: [0.33948117 0.25951509 0.33509486 0.36834898 0.41233402 0.18840958]

# %% [markdown]
# #### Obtaining The Feature Importance

# %%
# Get feature importance from the first base estimator
feature_importance = multi_output_model.estimators_[0].feature_importances_

# Create a dataframe with feature importance
data = pd.DataFrame(data=feature_importance, index=X_train.columns, columns=["score"])

# Sort the dataframe by score in descending order
data = data.sort_values(by="score", ascending=False)

# Plot the feature importance
data.plot(kind='bar', figsize=(15,6), title='Feature Importance')
plt.xlabel('Features')
plt.ylabel('Score')
plt.grid()
plt.show();

# %% [markdown]
# #### Make a Dataframe with the most important features

# %%
Cleaned_data.columns
# Out:
# Index(['earcpehp_25+', 'crpd', 'pcypesfm', 'pc_24_59_thlp', 'nerece',
#        'pseb_12lse', 'pcypepfm', 'crlsnd', 'earclshp_25+', 'ptmrepeagpi',
#        'ppp_2_cg', 'gils', 'crlsd', 'crusnd', 'ofspsa', 'ppels_2_cg',
#        'ptwmrseagpi', 'ofsalssa', 'crusd', 'gip', 'ofsussa', 'geeduv',
#        'pspmlsrbs', 'pspmprbs', 'nerpp', 'earcuse_25+', 'naspi', 'pyalmlpdl',
#        'pcypelsfr', 'crpnd'],
#       dtype='string')

# %%
most_important_features = X_train.drop([ 'ptwmrseagpi', 'ppels_2_cg','ofsussa','earcuse_25+','pseb_12lse',
                                        'naspi','earclshp_25+','pspmprbs','gils','ofspsa', 'pcypesfm'], axis=1).columns

new_X_train = X_train[most_important_features]
new_X_train.head()
# Out:
#       earcpehp_25+  pc_24_59_thlp  nerece  pcypepfm  ptmrepeagpi  ppp_2_cg  \
# 1549         93.00          78.19   50.61     52.73         1.00     22.63
# 1457         93.00          78.19   38.42     52.73         1.00      0.20
# 554          76.86          78.19   66.31     52.73         1.10     11.39
# 2081         93.00          78.19   50.61     52.73         1.00      2.50
# 151          82.64          78.19   69.09     68.47         1.15      1.35
#
#       ofsalssa      gip  geeduv  pspmlsrbs   nerpp  pyalmlpdl  pcypelsfr
# 1549    24.560   85.590    4.61      72.53  10.620       28.0      69.24
# 1457    48.940   95.440    7.33      72.53  29.640       28.0      69.24
# 554      0.130   92.850    7.07      72.53  30.190       28.0      69.24
# 2081     4.875   96.345    3.95      72.53  66.155       28.0      69.24
# 151     44.620  104.470    2.45      77.83  97.920       28.0      83.39

# %%
new_X_train= new_X_train.rename(columns={'earcuse_25+':'earcuse_twnetyfive', 'earclshp_25+':'earclshp_twentyfive'})

# %%
scaler = StandardScaler()
new_X_train_scaled = pd.DataFrame(scaler.fit_transform(new_X_train), columns=new_X_train.columns, index=new_X_train.index)
new_X_test_scaled = pd.DataFrame(scaler.transform(x_test[most_important_features]),
                                 columns=new_X_train.columns, index=x_test.index)

# %% [markdown]
# #### Retrain the model with the new best features

# %%
# Define the base model
base_model = GradientBoostingRegressor(random_state=0)

# Create MultiOutputRegressor with the base model
multi_output_model = MultiOutputRegressor(base_model)

# Fit the MultiOutputRegressor model
multi_output_model.fit(new_X_train_scaled, y_train)

# Evaluate the model
print('Performance of Gradient Boost on Test set:')
print('==' * 28)
print('Test set:')
print("**" * 8)
evaluate_model(multi_output_model, new_X_test_scaled, y_test)
print('\n')
# Out:
# MultiOutputRegressor(estimator=GradientBoostingRegressor(random_state=0))
# Performance of Gradient Boost on Test set:
# ========================================================
# Test set:
# ****************
# MSE: [ 7.63306744  4.60702103  8.22187312  9.04879005 13.88177572  3.42590051]
# MAE: [0.2914417  0.25057897 0.302022   0.34046943 0.45171161 0.16736242]

# %% [markdown]
# #### Comparison of predictions against actual

# %%
import pandas as pd

# Get predictions
y_pred = multi_output_model.predict(new_X_test_scaled)

# Create a DataFrame to compare the actual values with the predicted values
# Assuming y_test is a DataFrame with appropriate column names
y_test_df = pd.DataFrame(y_test, columns=['crpd', 'crpnd', 'crlsd', 'crlsnd', 'crusnd', 'crusd'])
y_pred_df = pd.DataFrame(y_pred, columns=['crpd_pred', 'crpnd_pred', 'crlsd_pred', 'crlsnd_pred', 'crusnd_pred', 'crusd_pred'])

# Concatenate the actual and predicted values for comparison
comparison_df = pd.concat([y_test_df.reset_index(drop=True), y_pred_df.reset_index(drop=True)], axis=1)

# Display the comparison DataFrame
comparison_df.head(2)
# Out:
#     crpd  crpnd  crlsd  crlsnd  crusnd  crusd  crpd_pred  crpnd_pred  \
# 0  41.84  79.94  21.32    62.2   40.75    9.6  41.840264   79.939363
# 1  41.84  79.94  21.32    62.2   40.75    9.6  41.840264   79.939363
#
#    crlsd_pred  crlsnd_pred  crusnd_pred  crusd_pred
# 0   21.320342     62.20015    40.751022    9.614933
# 1   21.318315     62.20015    40.751022    9.599468

# %% [markdown]
# #### Visualize the performance on Test data

# %%
target_columns = ['crpd', 'crpnd', 'crlsd', 'crlsnd', 'crusnd', 'crusd']

plt.figure(figsize=(20, 15))

for i, column in enumerate(target_columns):
    plt.subplot(2, 3, i+1)
    plt.scatter(y_test_df[column], y_pred_df[f'{column}_pred'], alpha=0.5)
    plt.plot([y_test_df[column].min(), y_test_df[column].max()],
             [y_test_df[column].min(), y_test_df[column].max()], 'r--', lw=2)
    plt.xlabel(f'Actual {column}')
    plt.ylabel(f'Predicted {column}')
    plt.title(f'Actual vs Predicted {column}')
    plt.grid(True)

plt.tight_layout()
plt.show();

# %% [markdown]
# #### Model comparison using mean squared error and mean absolute error

# %%
pip install PrettyTable
# Out:
# Collecting PrettyTable
#   Downloading prettytable-3.10.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.11/site-packages (from PrettyTable) (0.2.5)
# Downloading prettytable-3.10.0-py3-none-any.whl (28 kB)
# Installing collected packages: PrettyTable
# Successfully installed PrettyTable-3.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#Constructing the result summary
from prettytable import PrettyTable
task1_result = PrettyTable()
task1_result.field_names = ["Regressor",  "MAE_crpd", "MAE_crpnd", "MAE_crlsd", "MAE_crlsnd", "MAE_crusnd", "MAE_crusd"]
task1_result.add_row(['XGBR',  0.29911403, 0.24729523, 0.25878531, 0.37450027, 0.53036252 ,0.18669709])
task1_result.add_row(['GBR',  0.29435861, 0.2528487,  0.29499228, 0.33830164, 0.46666998, 0.16252451])
task1_result.add_row(['RFReg',0.34951169, 0.2705747,  0.38567613, 0.38904797, 0.41150095, 0.24455274])
task1_result.add_row(['MLPReg', 3.55129996, 7.55046495, 1.63934904 ,5.30806786, 3.31357662, 0.58508552])
task1_result.add_row(['ENReg', 0.36858173, 0.32357727, 0.39810011, 0.38899657, 0.34757865, 0.22691069])


print('Result Summary for All Regressors:')
print(task1_result)
# Out:
# Result Summary for All Regressors:
# +-----------+------------+------------+------------+------------+------------+------------+
# | Regressor |  MAE_crpd  | MAE_crpnd  | MAE_crlsd  | MAE_crlsnd | MAE_crusnd | MAE_crusd  |
# +-----------+------------+------------+------------+------------+------------+------------+
# |    XGBR   | 0.29911403 | 0.24729523 | 0.25878531 | 0.37450027 | 0.53036252 | 0.18669709 |
# |    GBR    | 0.29435861 | 0.2528487  | 0.29499228 | 0.33830164 | 0.46666998 | 0.16252451 |
# |   RFReg   | 0.34951169 | 0.2705747  | 0.38567613 | 0.38904797 | 0.41150095 | 0.24455274 |
# |   MLPReg  | 3.55129996 | 7.55046495 | 1.63934904 | 5.30806786 | 3.31357662 | 0.58508552 |
# |   ENReg   | 0.36858173 | 0.32357727 | 0.39810011 | 0.38899657 | 0.34757865 | 0.22691069 |
# +-----------+------------+------------+------------+------------+------------+------------+

# %% [markdown]
# #### Save the model for testing and deployment

# %%
# Save the trained model to a file
import pickle as pkl
filename = 'predictor_saved.sav'
with open(filename, 'wb') as file:
    pkl.dump(multi_output_model, file)

print(f'Model saved to {filename}')
# Out:
# Model saved to predictor_saved.sav

# %% [markdown]
# #### Test Saved Model

# %%
# Load the model from disk for prediction.
import joblib
rainfall_model = joblib.load('predictor_saved.sav')
input_data= (72.53,	85.590,	24.560,	22.63,	78.19,	50.61,
             10.620,	28.0,	93.00,	1.00,	4.61,	52.73,	69.24)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = rainfall_model.predict(input_data_reshaped)

# Print the prediction
print('Prediction:', prediction);
# Out:
# Prediction: [[23.23226568 57.95871838 18.41987725 53.29559224 40.14274354  7.62473761]]

# %% [markdown]
# # Conclusion
# <a id='conc'></a>

# %% [markdown]
# # Recommendation
# <a id='rec'></a>

# %% [markdown]
# # Limitation
# <a id='lit'></a>
# > During this project, we had some limitations that did not allow us to apply some other methods.
# - If we had data  that contains the responses of the students in **texts formats**, we would have been able to also include some sentimental analysis in our project so that we can know the real mind of the students towards education, hence, informing us better on whether a student wants to study or not.
